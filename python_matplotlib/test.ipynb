# %%
import matplotlib.pyplot as plt
from matplotlib import rc

def setHangeul(font_name = 'Malgun Gothic', fontSize = 12, fontColor = 'green') :
    rc('font', family = font_name)
    font1['size'] = fontSize
    font1['color'] = fontColor

def dataAnalysis() :
    make_ydata()
    return

def plotData(loc_list = 'best') :
    plt.plot(xdata, ydata, label = 'y = 2x')
    plt.xlim(0, 35)
    plt.ylim(0, 70)
    plt.xticks(list(range(0, 35, 2)))
    plt.yticks(list(range(0, 70, 5)))
    plt.grid(True)
    plt.legend(loc = loc_list)
    plt.title(' X/Y축의 범위와 눈금 설정 ')
    plt.xlabel('x축')
    plt.ylabel('y축')
    plt.show()

def make_ydata() :
    for x in xdata :
        y = 2 * x
        ydata.append(y)

font1 = {}
xdata = list(range(30))
ydata = []
setHangeul()
dataAnalysis()
plotData()

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt

date = list(range(1, 11))
min_temp = [7.3, 3.5, 7.2, 4.5, 3.5, 8.3, 7.7, 6.4, 9.3, 6.3]
max_temp = [15, 16.3, 15.2, 17.5, 18.3, 20.1, 18.8, 17.5, 14.2, 15.3]

plt.plot(date, min_temp, label = '최저기온', color = 'red', linestyle = '-', marker = 'o')
plt.plot(date, max_temp, label = '최고기온', color = 'blue', linestyle = '-.', marker = 'x')
plt.legend(loc = 'best')
plt.xlabel('date')
plt.ylabel('온도')
plt.title('10년 동안 최저 / 최고 온도')

plt.show()

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family = 'Malgun Gothic')
font1 = {'size' : 18, 'color' : 'blue'}
xdata = ['안지영', '홍지수', '황예린']
ydata1 = [90, 85, 88]
ydata2 = [83, 88, 91]

plt.plot(xdata, ydata1, label = '국어', color = 'red', linestyle = '-', marker = 'o')
plt.plot(xdata, ydata2, label = '영어', color = 'blue', linestyle = '-.', marker = 'x')
plt.legend(loc = 'best')
plt.title('국어, 영어 성적')

plt.show()

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from matplotlib import rc
import random

rc('font', family = 'Malgun Gothic')

font1 = {'size' : 15, 'color' : 'red'}

def make_random_list(num) :
    result = []
    for i in range(num) :
        result.append(random.randrange(1, 7))
    return result

count = 10
y = make_random_list(count)
x = list(range(1, 11))

plt.title('주사위 10회 던지기', fontdict = font1)
plt.bar(x, y)
plt.xticks(x)
plt.yticks([1, 2, 3, 4, 5, 6])
plt.xlabel('던진 회수')
plt.ylabel('주사위 눈')
plt.grid(False)

plt.show()
